# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv("covid_data.csv")
data = data[["Province_State","Country_Region","Last_Update","Lat","Long_","Confirmed","Recovered","Deaths","Active"]]
data.columns = ["State","Country","Update","Latitude","Longitude","Confirmed","Recovered","Deaths","Active"]
print(data.head())
# Out:
#   State      Country        Update  Latitude  Longitude  Confirmed  Recovered  \
# 0   NaN  Afghanistan  1.621603e+12  33.93911  67.709953      64575      55790
# 1   NaN      Albania  1.621603e+12  41.15330  20.168300     132118     127869
# 2   NaN      Algeria  1.621603e+12  28.03390   1.659600     126156      87902
# 3   NaN      Andorra  1.621603e+12  42.50630   1.521800      13569      13234
# 4   NaN       Angola  1.621603e+12 -11.20270  17.873900      31661      26483
#
#    Deaths  Active
# 0    2772    6013
# 1    2440    1809
# 2    3401   34853
# 3     127     208
# 4     704    4474

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      595 non-null    str
#  1   Country    766 non-null    str
#  2   Update     764 non-null    float64
#  3   Latitude   748 non-null    float64
#  4   Longitude  748 non-null    float64
#  5   Confirmed  766 non-null    int64
#  6   Recovered  766 non-null    int64
#  7   Deaths     766 non-null    int64
#  8   Active     766 non-null    int64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 54.0 KB
# None

# %%
data['State'] = data['State'].fillna(data['State'].mode()[0])
data['Update'] = data['Update'].fillna(data['Update'].mean())
data['Latitude'] = data['Latitude'].fillna(data['Latitude'].mean())
data['Longitude'] = data['Longitude'].fillna(data['Longitude'].mean())

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      766 non-null    str
#  1   Country    766 non-null    str
#  2   Update     766 non-null    float64
#  3   Latitude   766 non-null    float64
#  4   Longitude  766 non-null    float64
#  5   Confirmed  766 non-null    int64
#  6   Recovered  766 non-null    int64
#  7   Deaths     766 non-null    int64
#  8   Active     766 non-null    int64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 54.0 KB
# None

# %%
top_ten_countries = pd.DataFrame(data.groupby("Country")["Confirmed"].sum().sort_values(ascending=False).head(10))
top_ten_countries.reset_index(inplace=True)
print(top_ten_countries)
one = px.scatter(top_ten_countries, x="Country", y="Confirmed", size="Confirmed", color="Country",size_max=120,title="Top 10 Countries with Highest Confirmed Cases")
one.show()
one.write_html("top_ten_countries.html")
# Out:
#           Country  Confirmed
# 0              US   33057486
# 1           India   26031991
# 2          Brazil   15894094
# 3          France    5979099
# 4          Turkey    5160423
# 5          Russia    4926717
# 6  United Kingdom    4471065
# 7           Italy    4178261
# 8         Germany    3642568
# 9           Spain    3631661
